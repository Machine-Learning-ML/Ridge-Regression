# %%
import numpy as np
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X = np.random.rand(100,1) * 10
Y = 2.5 * X.squeeze() + np.random.randn(100) * 2

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
ridge_reg = Ridge(alpha=1.0)
ridge_reg.fit(X_train, Y_train)

Y_pred = ridge_reg.predict(X_test)

# %%
mse = mean_squared_error(Y_test, Y_pred)

print(f"mean Squared Error: {mse}")
print(f"Coefficients: {ridge_reg.coef_}")
# Out:
# mean Squared Error: 2.876410321803687
# Coefficients: [2.47352163]

# %% [markdown]
# #### Visualise the Results

# %%
import matplotlib.pyplot as plt

plt.scatter(X_test, Y_test, color="b", label="Acutal Data")
plt.plot(X_test, Y_pred, color="red", linewidth=2, label="Predicted Line")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Ridge Regressin Reuslts")
plt.legend()
plt.show()
